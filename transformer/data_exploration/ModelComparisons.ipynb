# %%
import pandas as pd
import matplotlib.pyplot as plt
import ml_utils.save_io as io
import numpy as np
import os
import seaborn as sns

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
def get_df(models, model_names=None):
    """
    Takes a list of model directories and extracts the training information from them.
    
    models: list of directory paths
        each directory must contain a csv named "model_data.csv"
    model_names: list of str or None
        the corresponding names of the models if different than the end point folder name
    """
    df = pd.DataFrame()
    if model_names is None:
        model_names = [m.split("/")[-1] for m in models]
    for model_path,model_name in zip(models,model_names):
        df_path = os.path.join(model_path,"model_data.csv")
        if not os.path.exists(df_path): 
            print("Could not find", df_path)
            continue
        new_df = pd.read_csv(df_path,sep="!")
        new_df['Model Name'] = model_name
        df = df.append(new_df,sort=True)
    return df

# %%
main_path = os.path.expanduser("/data2/pdplab/grantsrb/transformer/")

# %%
exp_folder = "/data2/pdplab/grantsrb/transformer/fixedidxs/"
model_folders = io.get_model_folders(os.path.join(main_path,exp_folder),True)
model_folders
# Out:
# ['/data2/pdplab/grantsrb/transformer/fixedidxs/fixedidxs_0_lr0.00025']

# %%
models = []
idxs = list(range(len(model_folders)))
# idxs = [0,2]
for idx in idxs:
    models.append(model_folders[idx])
models
# Out:
# ['/data2/pdplab/grantsrb/transformer/fixedidxs/fixedidxs_0_lr0.00025']

# %%
model_names = None

# %%
df = get_df(models,model_names)
df
# Out:
#                Model Name                                           amp_dict  \
# 0   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 1   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 2   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 3   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 4   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 5   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 6   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 7   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 8   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 9   fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 10  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 11  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 12  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 13  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 14  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 15  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 16  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 17  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 18  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 19  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 20  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 21  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 22  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 23  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 24  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 25  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 26  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 27  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 28  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 29  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 30  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 31  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 32  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 33  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 34  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 35  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 36  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 37  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 38  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 39  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 40  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 41  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 42  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 43  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 44  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 45  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 46  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 47  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 48  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 49  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
# 50  fixedidxs_0_lr0.00025  OrderedDict([('loss_scaler0', {'loss_scale': 1...
#
#     epoch  seed  step_num  train_acc  train_indy  train_loss   val_acc  \
# 0       0     3      1000   0.000531    0.191994    6.660544  0.000625
# 1       1     3      2000   0.001813    0.286026    5.085935  0.005625
# 2       2     3      3000   0.002656    0.341398    4.394028  0.003125
# 3       3     3      4000   0.003781    0.389671    3.889831  0.008125
# 4       4     3      5000   0.005594    0.426723    3.530650  0.016875
# 5       5     3      6000   0.006094    0.455178    3.262047  0.007500
# 6       6     3      7000   0.007219    0.474326    3.089824  0.010625
# 7       7     3      8000   0.009406    0.492127    2.934314  0.011250
# 8       8     3      9000   0.010188    0.501695    2.851595  0.008125
# 9       9     3     10000   0.010094    0.514504    2.746170  0.015625
# 10     10     3     11000   0.012656    0.524036    2.674553  0.021250
# 11     11     3     12000   0.013187    0.529394    2.620135  0.015625
# 12     12     3     13000   0.013656    0.536971    2.559840  0.020625
# 13     13     3     14000   0.011906    0.540971    2.524997  0.022500
# 14     14     3     15000   0.014594    0.546540    2.488752  0.033750
# 15     15     3     16000   0.014156    0.552154    2.445396  0.036875
# 16     16     3     17000   0.016438    0.554224    2.416992  0.034375
# 17     17     3     18000   0.016563    0.557890    2.401131  0.029375
# 18     18     3     19000   0.015406    0.559243    2.379897  0.040625
# 19     19     3     20000   0.015719    0.563308    2.351962  0.035625
# 20     20     3     21000   0.017031    0.567356    2.320845  0.031250
# 21     21     3     22000   0.015437    0.570221    2.302687  0.035000
# 22     22     3     23000   0.014906    0.569757    2.299313  0.047500
# 23     23     3     24000   0.014719    0.575469    2.259902  0.048750
# 24     24     3     25000   0.018156    0.574269    2.268506  0.051875
# 25     25     3     26000   0.016844    0.577166    2.248789  0.048125
# 26     26     3     27000   0.016344    0.578583    2.231102  0.037500
# 27     27     3     28000   0.018344    0.580322    2.219654  0.053750
# 28     28     3     29000   0.017313    0.582174    2.213224  0.043750
# 29     29     3     30000   0.016250    0.584143    2.192269  0.046875
# 30     30     3     31000   0.018875    0.585610    2.180002  0.045000
# 31     31     3     32000   0.019156    0.586754    2.168240  0.040000
# 32     32     3     33000   0.018281    0.587511    2.163265  0.068125
# 33     33     3     34000   0.019344    0.592709    2.125468  0.020000
# 34     34     3     35000   0.020281    0.593688    2.117409  0.031250
# 35     35     3     36000   0.018562    0.594450    2.109991  0.020625
# 36     36     3     37000   0.022531    0.596203    2.099710  0.024375
# 37     37     3     38000   0.018344    0.599112    2.076136  0.025625
# 38     38     3     39000   0.019031    0.596713    2.088934  0.028125
# 39     39     3     40000   0.020969    0.595521    2.100640  0.029375
# 40     40     3     41000   0.020375    0.597552    2.086234  0.045625
# 41     41     3     42000   0.020813    0.600116    2.072048  0.025625
# 42     42     3     43000   0.019062    0.600274    2.068059  0.038750
# 43     43     3     44000   0.019688    0.601005    2.059794  0.043750
# 44     44     3     45000   0.021844    0.603415    2.044914  0.055000
# 45     45     3     46000   0.020000    0.604085    2.038266  0.045625
# 46     46     3     47000   0.021406    0.604525    2.036226  0.029375
# 47     47     3     48000   0.018906    0.603522    2.039528  0.063125
# 48     48     3     49000   0.021438    0.604479    2.033217  0.046875
# 49     49     3     50000   0.020219    0.605175    2.030552  0.066250
# 50     50     3     51000   0.020969    0.606999    2.012453  0.043750
#
#     val_bleu  val_indy   val_loss
# 0   0.028404  0.061421   8.980907
# 1   0.057783  0.085550   9.407697
# 2   0.062390  0.089514   9.748605
# 3   0.081971  0.109803  10.607985
# 4   0.086712  0.113391   9.883579
# 5   0.097606  0.114669  10.259294
# 6   0.095978  0.111545  10.619535
# 7   0.106533  0.122750  11.030451
# 8   0.099463  0.124514  11.001168
# 9   0.000000  0.138432  10.984494
# 10  0.000000  0.153938  10.697062
# 11  0.000000  0.151534  10.953437
# 12  0.000000  0.153172  10.784340
# 13  0.000000  0.167236  10.733751
# 14  0.000000  0.165362  10.856589
# 15  0.000000  0.180787  10.599209
# 16  0.000000  0.172885  10.918659
# 17  0.000000  0.165158  11.289550
# 18  0.000000  0.180578  11.086151
# 19  0.000000  0.192001  11.323237
# 20  0.000000  0.181200  10.942784
# 21  0.000000  0.197612  10.856139
# 22  0.000000  0.193683  11.087905
# 23  0.000000  0.193424  11.142107
# 24  0.000000  0.212256  10.958755
# 25  0.000000  0.192097  10.945186
# 26  0.000000  0.196075  11.173169
# 27  0.000000  0.222000  10.852949
# 28  0.000000  0.181935  11.223356
# 29  0.000000  0.203445  11.231956
# 30  0.000000  0.209512  10.949851
# 31  0.000000  0.207684  11.411524
# 32  0.000000  0.239190  10.889894
# 33  0.258793  0.154102  12.895858
# 34  0.281901  0.173604  12.378168
# 35  0.279997  0.167717  12.253041
# 36  0.292408  0.173449  12.001753
# 37  0.261866  0.176797  11.622930
# 38  0.252126  0.170468  12.757569
# 39  0.268147  0.169149  12.422231
# 40  0.275786  0.182041  12.806672
# 41  0.276850  0.164855  12.793451
# 42  0.291463  0.183648  11.811345
# 43  0.286950  0.186303  12.049873
# 44  0.303758  0.209565  11.464120
# 45  0.292132  0.199387  11.991410
# 46  0.302513  0.192295  12.088859
# 47  0.323703  0.230215  11.255156
# 48  0.312398  0.210368  11.870735
# 49  0.316004  0.221955  12.076091
# 50  0.317406  0.207760  12.333185

# %%
# idx = ((df['seed']=="0")|(df['seed']=="4"))&(df['egoCentered']>=1)
# filtered_df = df.loc[idx]
filtered_df = df

# %%
x = "step_num"
y = "val_bleu"
hue = None
style = None

# %%
fig = plt.figure(figsize=(15,10))
sns.lineplot(x=x, 
             y=y,
             hue=hue,
             style=style,
             data=filtered_df,
             linewidth=3)
# plt.ylim([0,.75])
# plt.xlim([-1,125])
plt.title("Validation Bleu Score",fontsize=35)
plt.ylabel("Bleu Score (0-1)",fontsize=30)
plt.xlabel("Steps", fontsize=30)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
# Out:
# (array([-0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35]),
#  <a list of 9 Text major ticklabel objects>)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
seeds = ["Vaswani 2017", "Reproduced Result"]
bleus = [0.273, 0.32937]
ax.bar(seeds, bleus)
plt.title("BLEU Scores",fontsize=35)
plt.ylabel("BLEU (0-1)", fontsize=30)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.show()

# %%
fig = plt.figure(figsize=(15,10))
sns.lineplot(x="epoch", 
             y=y,
             hue=hue,
             style=style,
             data=filtered_df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# plt.ylim([0,.2])
# plt.ylim([0,-.3])
# plt.xlim([-1,75])
plt.title("Training Loss Comparison",fontsize=25)
plt.ylabel("Mean Squared Error",fontsize=17)
plt.xlabel("Epoch", fontsize=17)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# plt.legend(fontsize=20)
# Out:
# No handles with labels found to put in legend.
# (array([-0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35]),
#  <a list of 9 Text major ticklabel objects>)

# %% [markdown]
# ## Seed Deviations

# %% [markdown]
# This is a way to compare differences by seed

# %%
seed_avgs_df = df.groupby(["seed", "epoch"])[y].mean().reset_index()
seed_avgs_df['seed_avg'] = seed_avgs_df[y]
del seed_avgs_df[y]

# %%
seed_df = df.merge(seed_avgs_df,how="left",on=["seed","epoch"])
seed_df
# Out:
#                                             Model Name  absoluteCoords  \
# 0    tightwindowRNN_0_seed2_egoCentered1_absoluteCo...               0
# 1    tightwindowRNN_0_seed2_egoCentered1_absoluteCo...               0
# 2    tightwindowRNN_0_seed2_egoCentered1_absoluteCo...               0
# 3    tightwindowRNN_0_seed2_egoCentered1_absoluteCo...               0
# 4    tightwindowRNN_0_seed2_egoCentered1_absoluteCo...               0
# ..                                                 ...             ...
# 592  tightwindowRNN_11_seed5_egoCentered0_absoluteC...               1
# 593  tightwindowRNN_11_seed5_egoCentered0_absoluteC...               1
# 594  tightwindowRNN_11_seed5_egoCentered0_absoluteC...               1
# 595  tightwindowRNN_11_seed5_egoCentered0_absoluteC...               1
# 596  tightwindowRNN_11_seed5_egoCentered0_absoluteC...               1
#
#      egoCentered  epoch model_class    model_type  obj_recog  randomizeObjs  \
# 0              1      0  RNNLocator   EgoRelative      False              0
# 1              1      1  RNNLocator   EgoRelative      False              0
# 2              1      2  RNNLocator   EgoRelative      False              0
# 3              1      3  RNNLocator   EgoRelative      False              0
# 4              1      4  RNNLocator   EgoRelative      False              0
# ..           ...    ...         ...           ...        ...            ...
# 592            0     37  RNNLocator  AlloAbsolute      False              0
# 593            0     38  RNNLocator  AlloAbsolute      False              0
# 594            0     39  RNNLocator  AlloAbsolute      False              0
# 595            0     40  RNNLocator  AlloAbsolute      False              0
# 596            0     41  RNNLocator  AlloAbsolute      False              0
#
#      restrictCamera seed  ...  train_loss  train_obj_acc  train_obj_loss  \
# 0                 0    2  ...    1.192875            0.0             0.0
# 1                 0    2  ...    0.105277            0.0             0.0
# 2                 0    2  ...    0.086528            0.0             0.0
# 3                 0    2  ...    0.080621            0.0             0.0
# 4                 0    2  ...    0.073370            0.0             0.0
# ..              ...  ...  ...         ...            ...             ...
# 592               0    5  ...    0.039224            0.0             0.0
# 593               0    5  ...    0.042027            0.0             0.0
# 594               0    5  ...    0.041865            0.0             0.0
# 595               0    5  ...    0.042597            0.0             0.0
# 596               0    5  ...    0.039970            0.0             0.0
#
#      train_pred_loss  train_rew  train_rew_loss   val_rew    Model Type  \
# 0           0.423030  -1.334064        8.121484 -0.266142   EgoRelative
# 1           0.111290  -0.222986        0.051160 -0.210384   EgoRelative
# 2           0.093561  -0.187189        0.023232 -0.093294   EgoRelative
# 3           0.086993  -0.173985        0.023281 -0.351253   EgoRelative
# 4           0.079278  -0.158558        0.020191 -0.136416   EgoRelative
# ..               ...        ...             ...       ...           ...
# 592         0.042788  -0.085576        0.007148 -0.117910  AlloAbsolute
# 593         0.045803  -0.091606        0.008042 -0.085569  AlloAbsolute
# 594         0.045711  -0.091422        0.007250 -0.110639  AlloAbsolute
# 595         0.046433  -0.092865        0.008074 -0.081066  AlloAbsolute
# 596         0.043554  -0.087108        0.007710 -0.068155  AlloAbsolute
#
#      val_loss  seed_avg
# 0    0.266142  0.336753
# 1    0.210384  0.094889
# 2    0.093294  0.084631
# 3    0.351253  0.079050
# 4    0.136416  0.073975
# ..        ...       ...
# 592  0.117910  0.053228
# 593  0.085569  0.055867
# 594  0.110639  0.055892
# 595  0.081066  0.054755
# 596  0.068155  0.055473
#
# [597 rows x 22 columns]

# %%
seed_df['seed_deviation'] = seed_df[y]-seed_df['seed_avg']

# %%
fig = plt.figure(figsize=(15,10))
sns.lineplot(x="epoch", 
             y="seed_deviation",
             hue=hue,
             data=seed_df,
             )
plt.ylim([-.4,.4])
# plt.xlim([-1,125])
plt.title("Training Loss Comparison by Seed",fontsize=30)
plt.ylabel("Deviation From Seed Average",fontsize=25)
plt.xlabel("Epoch", fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=25)

# %%
fig = plt.figure(figsize=(15,10))
sns.lineplot(x="epoch", 
             y="seed_deviation",
             hue=hue,
             data=seed_df,
             )
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylim([-.2,.2])
plt.xlim([-1,75])
plt.suptitle("Training Loss Comparison",fontsize=25)
plt.ylabel("Mean Squared Error",fontsize=17)
plt.xlabel("Epoch", fontsize=17)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20)

# %%
sns.lineplot(x="epoch", y="train_pred_loss",data=df,hue="Model Name")
plt.ylim([0,.2])
plt.xlim([45,110])
plt.title("Training Loss Comparison",fontsize=25)
plt.ylabel("Mean Squared Error",fontsize=17)
plt.xlabel("Epoch", fontsize=17)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)

# %%
sns.lineplot(x="epoch", y="train_rew",data=comb_df,hue="Model Type")
plt.title("Training Reward Comparison",fontsize=25)
plt.ylabel("Mean Squared Error",fontsize=17)
plt.xlabel("Epoch", fontsize=17)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)

# %%
sns.lineplot(x="epoch", y="val_rew",data=comb_df,hue="Model Type")
plt.title("Validation Loss Comparison",fontsize=25)
plt.ylabel("Mean Squared Error",fontsize=17)
plt.xlabel("Epoch", fontsize=17)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=14)

# %% [markdown]
# ## Debugging

# %%
models
# Out:
# ['/home/grantsrb/src/locgame/training_scripts/search/search_0_egoCentered0_absoluteCoords0_seed0',
#  '/home/grantsrb/src/locgame/training_scripts/search/search_1_egoCentered0_absoluteCoords0_seed1',
#  '/home/grantsrb/src/locgame/training_scripts/search/search_2_egoCentered0_absoluteCoords1_seed0',
#  '/home/grantsrb/src/locgame/training_scripts/search/search_3_egoCentered0_absoluteCoords1_seed1',
#  '/home/grantsrb/src/locgame/training_scripts/search/search_4_egoCentered1_absoluteCoords0_seed0',
#  '/home/grantsrb/src/locgame/training_scripts/search/search_5_egoCentered1_absoluteCoords0_seed1']

# %%
df1 = pd.read_csv(os.path.join(models[0],"model_data.csv"),sep="!")
df2 = pd.read_csv(os.path.join(models[4],"model_data.csv"),sep="!")

# %%
df1
# Out:
#      val_rew  epoch  train_rew_loss  train_rew  train_pred_loss  train_loss
# 0  -1.824651      0        3.409225  -1.910497         0.781136    1.043945
# 1  -0.471600      1        2.086273  -1.506832         0.624149    0.770362
# 2  -0.249342      2        0.510073  -0.455068         0.214749    0.244282
# 3  -0.453887      3        0.112379  -0.365530         0.178816    0.172173
# 4  -0.322803      4        0.099665  -0.319833         0.157690    0.151887
# 5  -0.280210      5        0.121590  -0.351927         0.173200    0.168039
# 6  -0.386837      6        0.060758  -0.266912         0.133421    0.126154
# 7  -0.311598      7        0.092057  -0.294112         0.146312    0.140887
# 8  -0.286130      8        0.130521  -0.288875         0.142251    0.141078
# 9  -0.220878      9        0.070640  -0.241544         0.120017    0.115079
# 10 -0.199890     10        0.045893  -0.205926         0.102866    0.097169
# 11 -0.192918     11        0.048356  -0.204938         0.102373    0.096972
